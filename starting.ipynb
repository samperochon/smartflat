# %% [markdown]
# - importer des données
# - tester un modèle de landmark dessus
# - tester plusierus
# - comparer

# %%
from smartflat.utils.utils_io import fetch_output_path, get_data_root

data_root = get_data_root()
print(f"Data root: {data_root}")
# Out:
# Data root: D:\data-gold-final

# %% [markdown]
# # Importer des données

# %%
from smartflat.datasets.loader import get_dataset

# %%
# dset_hands = get_dataset(dataset_name="hand_landmarks", scenario="gold_")

dset_hands = get_dataset(dataset_name="hand_landmarks", scenario="gold_unprocessed")

# df_hands = dset_hands.metadata.copy()
# print(f"Videos awaiting hand landmark extraction: {len(df_hands)}")
# Out:
# ---------- smartflat dataset - root_dir: D:\data-gold-final ----------
# Exploring cuisine with 265 participants.
# sbj_folder : D:\data-gold-final\cuisine\G1_C1_BARMar_22022017
# video_paths before filter :['D:\\data-gold-final\\cuisine\\G1_C1_BARMar_22022017\\Tobii\\hand_landmarks_mediapipe_hDiQyQT_rgsf4RLWcEyR0A==.json', 'D:\\data-gold-final\\cuisine\\G1_C1_BARMar_22022017\\Tobii\\video_representations_VideoMAEv2_hDiQyQT_rgsf4RLWcEyR0A==.npy', 'D:\\data-gold-final\\cuisine\\G1_C1_BARMar_22022017\\Tobii\\hDiQyQT_rgsf4RLWcEyR0A==.mp4', 'D:\\data-gold-final\\cuisine\\G1_C1_BARMar_22022017\\Tobii\\hDiQyQT_rgsf4RLWcEyR0A==.wav', 'D:\\data-gold-final\\cuisine\\G1_C1_BARMar_22022017\\Tobii\\tracking_hand_landmarks', 'D:\\data-gold-final\\cuisine\\G1_C1_BARMar_22022017\\Tobii\\test.mp4']
# video_paths before filter :[]
# video_paths before filter :[]
# video_paths before filter :[]
# video_paths before filter :[]
# sbj_folder : D:\data-gold-final\cuisine\G2_P1_LEBAla_23022017
# ...

# %% [markdown]
# # Tester le modèle Mediapipe Existant sur cette vidéo pour extraire les json

# %% [markdown]
# # Tester avec un LSTM
